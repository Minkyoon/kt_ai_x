# %% [markdown]
# # 안녕하세요^^
# # AIVLE 미니 프로젝트에 오신 여러분을 환영합니다.
# * 본 과정에서는 실제 사례와 데이터를 기반으로 문제를 해결하는 전체 과정을 자기 주도형 실습으로 진행해볼 예정입니다.
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# ---

# %% [markdown]
# # (실습준비) 데이터 불러오기부터

# %%
import pandas as pd

# 학습/평가 데이터 로딩
train_x = pd.read_csv("train_x.csv")
train_y = pd.read_csv("train_y.csv")

test_y = pd.read_csv("test_y.csv")

# %%
test_y=test_y.iloc[:1416]

# %%
train_y
# Out:
#            총생활인구수
# 0      27011.5749
# 1      27092.9997
# 2      27163.6615
# 3      27415.3211
# 4      28010.0031
# ...           ...
# 42835  33060.4555
# 42836  32360.1898
# 42837  31417.3991
# 42838  30763.0563
# 42839  30404.2740
#
# [42840 rows x 1 columns]

# %%
test_y
# Out:
#           총생활인구수
# 0     30509.7386
# 1     30759.5067
# 2     31048.8787
# 3     31076.1092
# 4     31714.9309
# ...          ...
# 1411  32453.4947
# 1412  32073.9265
# 1413  31374.2576
# 1414  31127.4353
# 1415  31550.2525
#
# [1416 rows x 1 columns]

# %%
train_x
# Out:
#                1d          7d         14d         28d
# 0      27924.7614  30178.4841  30215.7510  31535.2200
# 1      27887.0119  30125.2091  30197.7155  31188.9174
# 2      28119.0554  30247.8400  30298.9381  31240.4974
# 3      28317.6555  30632.8111  30619.1491  31442.4314
# 4      29073.9680  31085.9805  31260.2082  31922.7751
# ...           ...         ...         ...         ...
# 42835  33928.2051  33980.5909  33985.4626  34154.9696
# 42836  33712.5348  33047.1323  33317.9921  32915.6079
# 42837  32144.4917  32033.9452  31703.0691  31783.7785
# 42838  32137.7017  31659.1453  32302.5886  31745.4525
# 42839  31641.1698  32114.6316  31597.6085  31856.9286
#
# [42840 rows x 4 columns]

# %%
train_x = train_x.values
train_y = train_y.values

# %%
train_x
# Out:
# array([[27924.7614, 30178.4841, 30215.751 , 31535.22  ],
#        [27887.0119, 30125.2091, 30197.7155, 31188.9174],
#        [28119.0554, 30247.84  , 30298.9381, 31240.4974],
#        ...,
#        [32144.4917, 32033.9452, 31703.0691, 31783.7785],
#        [32137.7017, 31659.1453, 32302.5886, 31745.4525],
#        [31641.1698, 32114.6316, 31597.6085, 31856.9286]])

# %% [markdown]
# ---

# %% [markdown]
# # 1. Machine Learning
# ## 이제 모델링을 해봅시다!
# + KeyPoint : 머신러닝 라이브러리를 토대로 모델링을 할 수 있다.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %%
plt.plot(train_x)
# Out:
# [<matplotlib.lines.Line2D at 0x2251249c940>,
#  <matplotlib.lines.Line2D at 0x2251249c7f0>,
#  <matplotlib.lines.Line2D at 0x2251249da20>,
#  <matplotlib.lines.Line2D at 0x2251249db40>]

# %% [markdown]
# ### 가. LinearRegression 부터 시작해봅시다.

# %% [markdown]
# #### [실습문제1] 머신러닝_1
# * Train과 Test로 나눈 데이터를 기준으로 LinearRegression 모델링을 진행하고 평가를 해주세요.
# * 성능지표 : RMSE, R-squared Score

# %%
# 아래에 실습코드를 작성하세요.

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2
from math import sqrt

LR_reg = LinearRegression()
LR_reg.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
pd.DataFrame(train_y[:1416]).count()
# Out:
# 0    1416
# dtype: int64

# %%
train_x
# Out:
# array([[27924.7614, 30178.4841, 30215.751 , 31535.22  ],
#        [27887.0119, 30125.2091, 30197.7155, 31188.9174],
#        [28119.0554, 30247.84  , 30298.9381, 31240.4974],
#        ...,
#        [32144.4917, 32033.9452, 31703.0691, 31783.7785],
#        [32137.7017, 31659.1453, 32302.5886, 31745.4525],
#        [31641.1698, 32114.6316, 31597.6085, 31856.9286]])

# %%
# Test 데이터로 성능을 평가해보세요.

for i in range(1,51):

    y_pred_LR = LR_reg.predict(train_x[-1416-i:-i])

    print('LinearRegression')
    print("Mean Squared Error : {0:.5f}".format(mse(test_y,y_pred_LR)))
    print("Root Mean Squared Error : {0:.5f}".format(sqrt(mse(test_y,y_pred_LR))))
    print("r2 : ", r2(test_y,y_pred_LR))
# Out:
# LinearRegression
# Mean Squared Error : 3933625.88730
# Root Mean Squared Error : 1983.33706
# r2 :  0.4494333629315119
# LinearRegression
# Mean Squared Error : 5348553.42201
# Root Mean Squared Error : 2312.69398
# r2 :  0.2513942212331086
# LinearRegression
# Mean Squared Error : 7260683.10205
# Root Mean Squared Error : 2694.56548
# r2 :  -0.016235400328393323
# LinearRegression
# Mean Squared Error : 9494933.56500
# Root Mean Squared Error : 3081.38501
# r2 :  -0.3289503861957206
# LinearRegression
# Mean Squared Error : 12022914.76113
# Root Mean Squared Error : 3467.40750
# r2 :  -0.6827771469509698
# LinearRegression
# Mean Squared Error : 14848186.84167
# Root Mean Squared Error : 3853.33451
# r2 :  -1.078213976165876
# LinearRegression
# Mean Squared Error : 17788109.42978
# Root Mean Squared Error : 4217.59522
# r2 :  -1.489697767190611
# LinearRegression
# Mean Squared Error : 20647097.53725
# Root Mean Squared Error : 4543.90774
# r2 :  -1.889853631740381
# LinearRegression
# Mean Squared Error : 23171879.39044
# Root Mean Squared Error : 4813.71783
# r2 :  -2.2432325991538637
# LinearRegression
# Mean Squared Error : 25122176.95793
# Root Mean Squared Error : 5012.20280
# r2 :  -2.516204356962561
# LinearRegression
# Mean Squared Error : 26321346.44859
# Root Mean Squared Error : 5130.43336
# r2 :  -2.684045105590743
# LinearRegression
# Mean Squared Error : 26744764.71197
# Root Mean Squared Error : 5171.53408
# r2 :  -2.743308486507537
# LinearRegression
# Mean Squared Error : 26467653.07845
# Root Mean Squared Error : 5144.67230
# r2 :  -2.704522789918023
# LinearRegression
# Mean Squared Error : 25460800.90751
# Root Mean Squared Error : 5045.86969
# r2 :  -2.563599573103863
# LinearRegression
# Mean Squared Error : 23684220.43101
# Root Mean Squared Error : 4866.64365
# r2 :  -2.3149419817491053
# LinearRegression
# Mean Squared Error : 21287192.93900
# Root Mean Squared Error : 4613.80461
# r2 :  -1.9794440459893914
# LinearRegression
# Mean Squared Error : 18541516.91108
# Root Mean Squared Error : 4305.98617
# r2 :  -1.5951478112984576
# LinearRegression
# Mean Squared Error : 15697231.71602
# Root Mean Squared Error : 3961.97321
# r2 :  -1.1970498275104977
# LinearRegression
# Mean Squared Error : 12892928.98231
# Root Mean Squared Error : 3590.67250
# r2 :  -0.8045479552795398
# LinearRegression
# Mean Squared Error : 10225787.94697
# Root Mean Squared Error : 3197.77860
# r2 :  -0.4312438047356504
# LinearRegression
# Mean Squared Error : 7765406.54466
# Root Mean Squared Error : 2786.64790
# r2 :  -0.08687859223572714
# LinearRegression
# Mean Squared Error : 5706049.21529
# Root Mean Squared Error : 2388.73381
# r2 :  0.201357623368547
# LinearRegression
# Mean Squared Error : 4239957.37822
# Root Mean Squared Error : 2059.11568
# r2 :  0.40655793359071746
# LinearRegression
# Mean Squared Error : 3666176.77281
# Root Mean Squared Error : 1914.72629
# r2 :  0.48686665317503175
# LinearRegression
# Mean Squared Error : 4244803.90231
# Root Mean Squared Error : 2060.29219
# r2 :  0.4058795939243671
# LinearRegression
# Mean Squared Error : 5655069.63039
# Root Mean Squared Error : 2378.03903
# r2 :  0.20849293806771607
# LinearRegression
# Mean Squared Error : 7556426.94181
# Root Mean Squared Error : 2748.89559
# r2 :  -0.057628937983844386
# LinearRegression
# Mean Squared Error : 9792501.11995
# Root Mean Squared Error : 3129.29722
# r2 :  -0.3705991786140759
# LinearRegression
# Mean Squared Error : 12302344.88174
# Root Mean Squared Error : 3507.46987
# r2 :  -0.7218873486343274
# LinearRegression
# Mean Squared Error : 15093971.99631
# Root Mean Squared Error : 3885.09614
# r2 :  -1.1126150885005255
# LinearRegression
# Mean Squared Error : 18011498.11081
# Root Mean Squared Error : 4243.99554
# r2 :  -1.5209641759431523
# LinearRegression
# Mean Squared Error : 20847075.48049
# Root Mean Squared Error : 4565.85977
# r2 :  -1.91784337627892
# LinearRegression
# Mean Squared Error : 23345710.30361
# Root Mean Squared Error : 4831.73988
# r2 :  -2.2675626966318783
# LinearRegression
# Mean Squared Error : 25254049.99774
# Root Mean Squared Error : 5025.34078
# r2 :  -2.5346618560038845
# LinearRegression
# Mean Squared Error : 26426645.22915
# Root Mean Squared Error : 5140.68529
# r2 :  -2.6987831608001414
# LinearRegression
# Mean Squared Error : 26842922.38213
# Root Mean Squared Error : 5181.01557
# r2 :  -2.757047042208505
# LinearRegression
# Mean Squared Error : 26554973.76336
# Root Mean Squared Error : 5153.15183
# r2 :  -2.716744556098395
# LinearRegression
# Mean Squared Error : 25510679.63101
# Root Mean Squared Error : 5050.80980
# r2 :  -2.5705808066648013
# LinearRegression
# Mean Squared Error : 23702649.75903
# Root Mean Squared Error : 4868.53672
# r2 :  -2.317521427136347
# LinearRegression
# Mean Squared Error : 21280534.83301
# Root Mean Squared Error : 4613.08301
# r2 :  -1.9785121497881248
# LinearRegression
# Mean Squared Error : 18511007.86248
# Root Mean Squared Error : 4302.44208
# r2 :  -1.5908776379851117
# LinearRegression
# Mean Squared Error : 15641986.60035
# Root Mean Squared Error : 3954.99515
# r2 :  -1.1893174913858537
# LinearRegression
# Mean Squared Error : 12806291.85505
# Root Mean Squared Error : 3578.58797
# r2 :  -0.7924218626705064
# LinearRegression
# Mean Squared Error : 10105458.47401
# Root Mean Squared Error : 3178.90838
# r2 :  -0.4144019913131616
# LinearRegression
# Mean Squared Error : 7608987.32374
# Root Mean Squared Error : 2758.43929
# r2 :  -0.06498550760950939
# LinearRegression
# Mean Squared Error : 5497226.74771
# Root Mean Squared Error : 2344.61655
# r2 :  0.23058528431421688
# LinearRegression
# Mean Squared Error : 3971266.23401
# Root Mean Squared Error : 1992.80361
# r2 :  0.44416506347888385
# LinearRegression
# Mean Squared Error : 3353265.38474
# Root Mean Squared Error : 1831.19234
# r2 :  0.5306630322829907
# LinearRegression
# Mean Squared Error : 3918722.26755
# Root Mean Squared Error : 1979.57628
# r2 :  0.4515193355268222
# LinearRegression
# Mean Squared Error : 5327201.42712
# Root Mean Squared Error : 2308.07310
# r2 :  0.2543827352300644

# %%
# 아래에 실습코드를 작성하세요.

plt.figure(figsize=(40,10))
plt.plot(test_y, color='r')
plt.plot(y_pred_LR)

# %%
y_pred_LR
# Out:
# array([[32934.13736217],
#        [33190.91719602],
#        [33318.43494351],
#        ...,
#        [32014.5951286 ],
#        [31955.2168081 ],
#        [31863.95132517]])

# %% [markdown]
# ### 나. 다음은 앙상블 기법을 토대로 랜덤포레스트와 그라디언부스팅을 활용해봅시다.

# %% [markdown]
# #### 1) 렌덤포레스트
# ##### 배깅의 일종으로 의사결정나무(Decision Tree) 여러 개를 모아서 숲을 랜덤으로 구성하고 이를 종합해서 최종 모델을 산출하는 기법이라고 할 수 있다.

# %% [markdown]
# #### [실습문제2] 머신러닝_2
# * Train과 Test로 나눈 데이터를 기준으로 렌덤포레스트로 모델을 학습을 진행하고 평가를 해주세요.
# * 성능지표 : RMSE, R-squared Score

# %%
# 아래에 실습코드를 작성하세요.

from sklearn.ensemble import RandomForestRegressor as RFR

RFR_reg = RFR()
RFR_reg.fit(train_x, train_y)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_17608\4150206231.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFR_reg.fit(train_x, train_y)
# RandomForestRegressor()

# %%
train_x
# Out:
# array([[27924.7614, 30178.4841, 30215.751 , 31535.22  ],
#        [27887.0119, 30125.2091, 30197.7155, 31188.9174],
#        [28119.0554, 30247.84  , 30298.9381, 31240.4974],
#        ...,
#        [32144.4917, 32033.9452, 31703.0691, 31783.7785],
#        [32137.7017, 31659.1453, 32302.5886, 31745.4525],
#        [31641.1698, 32114.6316, 31597.6085, 31856.9286]])

# %%
train_x[-1416:]
# Out:
# array([[32812.2781, 33070.6523, 32934.9892, 32711.1092],
#        [33051.5752, 33311.2075, 33197.8052, 33068.2607],
#        [33440.1737, 33183.0618, 33428.4441, 33123.8689],
#        ...,
#        [32144.4917, 32033.9452, 31703.0691, 31783.7785],
#        [32137.7017, 31659.1453, 32302.5886, 31745.4525],
#        [31641.1698, 32114.6316, 31597.6085, 31856.9286]])

# %%
# Test 데이터로 성능을 평가해보세요.

y_pred_RFR = RFR_reg.predict(train_x[-1416:])

print('RandomForestRegressor')
print("Mean Squared Error : {0:.5f}".format(mse(test_y,y_pred_RFR)))
print("Root Mean Squared Error : {0:.5f}".format(sqrt(mse(test_y,y_pred_RFR))))
print("r2 : ", r2(test_y,y_pred_RFR))
# Out:
# RandomForestRegressor
# Mean Squared Error : 3518780.36040
# Root Mean Squared Error : 1875.84124
# r2 :  0.5074968680001575

# %%
# 아래에 실습코드를 작성하세요.

plt.figure(figsize=(40,10))
plt.plot(test_y, color='r')
plt.plot(y_pred_RFR)

# %%
train_x
# Out:
# array([[27924.7614, 30178.4841, 30215.751 , 31535.22  ],
#        [27887.0119, 30125.2091, 30197.7155, 31188.9174],
#        [28119.0554, 30247.84  , 30298.9381, 31240.4974],
#        ...,
#        [32144.4917, 32033.9452, 31703.0691, 31783.7785],
#        [32137.7017, 31659.1453, 32302.5886, 31745.4525],
#        [31641.1698, 32114.6316, 31597.6085, 31856.9286]])

# %% [markdown]
# #### [실습문제3] 머신러닝_3
# * 렌덤포레스트로 학습한 모델의 feature_importances 또는 Shap value를 구해보세요.
# * 확인할 수 있는 내용으로 우리 모델에서의 인사이트를 정리해보세요.

# %%
# Feature의 중요도 확인

feature_names = [f"feature {i}" for i in range(train_x.shape[1])]
rfr_importances = RFR_reg.feature_importances_
forest_importances = pd.Series(rfr_importances, index = feature_names)
forest_importances
# Out:
# feature 0    0.163370
# feature 1    0.756379
# feature 2    0.045134
# feature 3    0.035117
# dtype: float64

# %%
# 확인할 수 있는 인사이트
# 1.
# 2.
# 3.

# %% [markdown]
# #### 2) GradientBoosting
# ##### 앞선 모델의 에러를 다음 모델의 예측 값으로 활용하면서 가중치 업데이트 하는데 경사하강법(Gradient Descent)를 활용해서 최적 모델을 만드는 기법

# %% [markdown]
# #### [실습문제4] 머신러닝_4
# * Train과 Test로 나눈 데이터를 기준으로 그라디언트부스팅으로 모델을 학습을 진행하고 평가를 해주세요.
# * 성능지표 : RMSE, R-squared Score

# %%
# 아래에 실습코드를 작성하세요.

from sklearn.ensemble import GradientBoostingRegressor as GBR

gbr_reg = GBR()
gbr_reg.fit(train_x, train_y)
# Out:
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb.py:570: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingRegressor()

# %%
# Test 데이터로 성능을 평가해보세요.

y_pred_gbr = gbr_reg.predict(train_x[-1416:])

print('GradientBoostingRegressor')
print("Mean Squared Error : {0:.5f}".format(mse(test_y,y_pred_gbr)))
print("Root Mean Squared Error : {0:.5f}".format(sqrt(mse(test_y,y_pred_gbr))))
print("r2 : ", r2(test_y,y_pred_gbr))
# Out:
# GradientBoostingRegressor
# Mean Squared Error : 3237017.38949
# Root Mean Squared Error : 1799.17131
# r2 :  0.5469335851134209

# %%
plt.figure(figsize=(40,10))
plt.plot(test_y, color='r')
plt.plot(y_pred_gbr)

# %% [markdown]
# #### [실습문제5] 머신러닝_5
# * 그라디언트부스팅으로 학습한 모델의 feature_importances 또는 Shap value를 구해보세요.
# * 확인할 수 있는 내용으로 우리 모델에서의 인사이트를 정리해보세요.

# %%
# Feature의 중요도 확인

feature_names = [f"feature {i}" for i in range(train_x.shape[1])]
gbr_importances = gbr_reg.feature_importances_
gradient_importances = pd.Series(gbr_importances, index = feature_names)
gradient_importances
# Out:
# feature 0    0.195561
# feature 1    0.620939
# feature 2    0.141132
# feature 3    0.042367
# dtype: float64

# %%
# 확인할 수 있는 인사이트
# 1.
# 2.
# 3.

# %% [markdown]
# ### 3) Self Choice Model
# ##### 앞선 교육과정에서 배운 머신러닝 모델 중 어떤 것이든 좋습니다. 원하는 모델을 선택해서 학습을 시켜보세요.

# %% [markdown]
# #### [실습문제6] 머신러닝_6
# * Train과 Test로 나눈 데이터를 기준으로 Self Choice Model로 모델을 학습을 진행하고 평가를 해주세요.
# * 성능지표 : RMSE, R-squared Score

# %%
# 아래에 실습코드를 작성하세요.

import xgboost

xgb_reg = xgboost.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75, colsample_bytree=1, max_depth=7)
xgb_reg.fit(train_x, train_y)
y_pred_xgb = xgb_reg.predict(test_x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\PC\ai-x 선도인재\drive-download-20221118T071811Z-001\3. 모델링_5차_생활인구 변수 4개.ipynb 셀 45 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/PC/ai-x%20%EC%84%A0%EB%8F%84%EC%9D%B8%EC%9E%AC/drive-download-20221118T071811Z-001/3.%20%EB%AA%A8%EB%8D%B8%EB%A7%81_5%EC%B0%A8_%EC%83%9D%ED%99%9C%EC%9D%B8%EA%B5%AC%20%EB%B3%80%EC%88%98%204%EA%B0%9C.ipynb#X62sZmlsZQ%3D%3D?line=4'>5</a> xgb_reg = xgboost.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75, colsample_bytree=1, max_depth=7)
#       <a href='vscode-notebook-cell:/c%3A/Users/PC/ai-x%20%EC%84%A0%EB%8F%84%EC%9D%B8%EC%9E%AC/drive-download-20221118T071811Z-001/3.%20%EB%AA%A8%EB%8D%B8%EB%A7%81_5%EC%B0%A8_%EC%83%9D%ED%99%9C%EC%9D%B8%EA%B5%AC%20%EB%B3%80%EC%88%98%204%EA%B0%9C.ipynb#X62sZmlsZQ%3D%3D?line=5'>6</a> xgb_reg.fit(train_x, train_y)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/PC/ai-x%20%EC%84%A0%EB%8F%84%EC%9D%B8%EC%9E%AC/drive-download-20221118T071811Z-001/3.%20%EB%AA%A8%EB%8D%B8%EB%A7%81_5%EC%B0%A8_%EC%83%9D%ED%99%9C%EC%9D%B8%EA%B5%AC%20%EB%B3%80%EC%88%98%204%EA%B0%9C.ipynb#X62sZmlsZQ%3D%3D?line=6'>7</a> y_pred_xgb = xgb_reg.predict(test_x)
#
# NameError: name 'test_x' is not defined

# %%
# Test 데이터로 성능을 평가해보세요.

print('Xgboost')
print("Mean Squared Error : {0:.5f}".format(mse(test_y,y_pred_xgb)))
print("Root Mean Squared Error : {0:.5f}".format(sqrt(mse(test_y,y_pred_xgb))))
print("r2 : ", r2(test_y,y_pred_xgb))
# Out:
# Xgboost
# Mean Squared Error : 3394860.05316
# Root Mean Squared Error : 1842.51460
# r2 :  0.733572549228307

# %%
# 아래에 실습코드를 작성하세요.

plt.figure(figsize=(40,10))
plt.plot(test_y, color='r')
plt.plot(y_pred_xgb)

# %% [markdown]
# #### [실습문제7] 머신러닝_7
# * Self Choice Model로 학습한 모델의 feature_importances 또는 Shap value를 구해보세요.
# * 확인할 수 있는 내용으로 우리 모델에서의 인사이트를 정리해보세요.

# %%
# Feature의 중요도 확인

xgboost.plot_importance(xgb_reg)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
# 확인할 수 있는 인사이트
# 1.
# 2.
# 3.

# %% [markdown]
# #### [실습문제8] 스케일링 test
# * Min Max Scale 함수를 활용하여 스케일링 후 위 모델에 적용하여 보세요.

# %%
# 아래에 실습코드를 작성하세요.
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(train_x)
scaled_train_x = scaler.transform(train_x)

# %%
scaler.fit(test_x)
scaled_test_x = scaler.transform(test_x)

# %%
# 아래에 실습코드를 작성하세요.

scaled_train_x
# Out:
# array([[0.15538966, 0.16070305],
#        [0.15600652, 0.14840061],
#        [0.16122772, 0.150233  ],
#        ...,
#        [0.18234751, 0.17842033],
#        [0.18210629, 0.16510552],
#        [0.16446693, 0.18128672]])

# %%
LR_reg.fit(scaled_train_x, train_y)
scaled_y_pred_LR = LR_reg.predict(scaled_test_x)

# %%
print('scaled_LinearRegression')
print("Mean Squared Error : {0:.5f}".format(mse(test_y,scaled_y_pred_LR)))
print("Root Mean Squared Error : {0:.5f}".format(sqrt(mse(test_y,scaled_y_pred_LR))))
print("r2 : ", r2(test_y,scaled_y_pred_LR))
# Out:
# scaled_LinearRegression
# Mean Squared Error : 4062798.12746
# Root Mean Squared Error : 2015.63839
# r2 :  0.6811529986068101

# %%
xgb_reg.fit(scaled_train_x, train_y)
scaled_y_pred_xgb = xgb_reg.predict(scaled_test_x)

# %%
print('scaled_Xgboost')
print("Mean Squared Error : {0:.5f}".format(mse(test_y,scaled_y_pred_xgb)))
print("Root Mean Squared Error : {0:.5f}".format(sqrt(mse(test_y,scaled_y_pred_xgb))))
print("r2 : ", r2(test_y,scaled_y_pred_xgb))
# Out:
# scaled_Xgboost
# Mean Squared Error : 4103087.02674
# Root Mean Squared Error : 2025.60782
# r2 :  0.6779911396314153

# %% [markdown]
# # 2. Deep Learning
# ## 이번엔 딥러닝 모델링을 해봅시다.

# %% [markdown]
# #### [실습문제9] 딥러닝_1
# * tensorflow 라이브러리를 활용한 모델을 자유롭게 만들어보세요.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
model1 = tf.keras.models.Sequential([
    Dense(128, activation='relu', input_shape=(2,)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1),])

model1.compile(optimizer = 'adam', loss = 'mse', metrics = ['mse'])

# %%
history1 = model1.fit(train_x, train_y, epochs= 5, validation_split=0.2)
# Out:
# Epoch 1/5
# 1084/1084 [==============================] - 2s 1ms/step - loss: 11543452.0000 - mse: 11543452.0000 - val_loss: 920623.1250 - val_mse: 920623.1250
# Epoch 2/5
# 1084/1084 [==============================] - 1s 1ms/step - loss: 2707352.2500 - mse: 2707352.2500 - val_loss: 1526692.7500 - val_mse: 1526692.7500
# Epoch 3/5
# 1084/1084 [==============================] - 1s 1ms/step - loss: 2711267.5000 - mse: 2711267.5000 - val_loss: 948988.8750 - val_mse: 948988.8750
# Epoch 4/5
# 1084/1084 [==============================] - 1s 1ms/step - loss: 2736805.5000 - mse: 2736805.5000 - val_loss: 944749.0000 - val_mse: 944749.0000
# Epoch 5/5
# 1084/1084 [==============================] - 1s 1ms/step - loss: 2755332.2500 - mse: 2755332.2500 - val_loss: 927861.1875 - val_mse: 927861.1875

# %%
y_pred_deep1 = model1.predict(test_x)

# %%
print('DEEP1')
print("Mean Squared Error : {0:.5f}".format(mse(test_y,y_pred_deep1)))
print("Root Mean Squared Error : {0:.5f}".format(sqrt(mse(test_y,y_pred_deep1))))
print("r2 : ", r2(test_y,y_pred_deep1))
# Out:
# DEEP1
# Mean Squared Error : 3446786.78800
# Root Mean Squared Error : 1856.55239
# r2 :  0.7294973569164542

# %%
plt.figure(figsize=(40,10))
plt.plot(test_y, color='r')
plt.plot(y_pred_deep1)
