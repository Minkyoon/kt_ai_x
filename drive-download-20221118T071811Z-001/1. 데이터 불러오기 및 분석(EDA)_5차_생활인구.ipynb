# %% [markdown]
# # 안녕하세요^^
# # 미니 프로젝트에 오신 여러분을 환영합니다.
#
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.

# %% [markdown]
# ## 기본 데이터
#
# [기본 데이터]
# * 서울시 특정구 특정동의 생활인구 데이터입니다.
#
#     * data_2017.csv
#     * data_2018.csv
#     * data_2019.csv
#     * data_2020.csv
#     * data_2021.csv
#     * data_2022.csv
#
#
# * 2017 ~ 2021년은 데이터 전부(train data), 2022년은 1월 ~ 6월(test data)까지 제공합니다.
#
# [변수 소개]
# * index : 날짜
# * 시간대 : 0 ~ 23
#
# * 총 생활 인구 수 : 생활 인구 합계
#
# * 각 성별, 연령대 별 생활 인구수

# %% [markdown]
# ---

# %% [markdown]
# # 1. 데이터 불러오기
# ## 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터라고 할 수 있습니다.
# + KeyPoint : 불러오고자 하는 데이터에 따라 자유롭게 변수로 지정할 수 있다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(여기서는 CSV 기준으로 진행)

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * Pandas 라이브러리를 활용해서 'data_2017.csv'파일을 'df2017' 변수에 저장하고 그 Shape을 확인하세요.
# * 아래에 'Pandas'를 Import하고 'data_2017.csv'파일을 불러오고 Shape을 확인하는 소스코드를 작성하고 실행해보세요.
# * 구분자(sep) : ','
# * index_col = 0

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
df17 = pd.read_csv('data_2017.csv', sep=',', index_col=0)
df17[0:50]
# Out:
#           기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 256    20170101      0  31535.2200      1945.4402         566.4588
# 680    20170101      1  31188.9174      1930.4766         562.1018
# 1104   20170101      2  31240.4974      1921.1864         559.3965
# 1528   20170101      3  31442.4314      1946.4476         566.7525
# 1952   20170101      4  31922.7751      1953.7713         568.8845
# 2376   20170101      5  33633.7304      2122.3666         617.9749
# 2800   20170101      6  34876.8006      2165.5627         630.5523
# 3224   20170101      7  35358.9775      2227.9843         648.7271
# 3648   20170101      8  36038.7688      2394.6462         697.2551
# 4072   20170101      9  37353.1794      2476.5581         721.1057
# 4496   20170101     10  37534.7596      2380.3937         693.1053
# 4920   20170101     11  38257.1671      2503.2104         728.8661
# 5344   20170101     12  38423.5288      2442.0413         711.0553
# ...

# %%
# 데이터 프레임의 Shape을 확인합니다.

df17.shape
# Out:
# (8760, 31)

# %% [markdown]
# ---

# %% [markdown]
# # 2. 추가 데이터 불러오기

# %% [markdown]
# #### [실습문제2] 추가데이터 불러오기
# * Pandas 라이브러리를 활용해서 'data_2018.csv' ~ 'data_2021.csv'를 df18 ~ df21로 각각 불러오고 'df_total'로 합쳐보세요. 그리고 Shape을 확인하세요.
# * 구분자(sep) : ','
# * index_col = 0

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df17 = pd.read_csv('data_2017.csv', sep=',', index_col=0)
df18 = pd.read_csv('data_2018.csv', sep=',', index_col=0)
df19 = pd.read_csv('data_2019.csv', sep=',', index_col=0)
df20 = pd.read_csv('data_2020.csv', sep=',', index_col=0)
df21 = pd.read_csv('data_2021.csv', sep=',', index_col=0)

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_total = pd.concat([df17,df18,df19,df20,df21])

# %%
# 데이터 프레임의 Shape을 확인합니다.

df_total.shape
# Out:
# (43512, 31)

# %% [markdown]
# #### [실습문제3] 추가데이터 불러오기
# * Pandas 라이브러리를 활용해서 'data_2022.csv'를 df_test로 불러오고 Shape을 확인하세요.
# * 구분자(sep) : ','
# * index_col = 0

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_test = pd.read_csv('data_2022.csv', sep=',', index_col=0)

# %%
# 데이터 프레임의 Shape을 확인합니다.

df_test.shape
# Out:
# (4344, 31)

# %% [markdown]
# #### [실습문제4] 데이터 확인
# * df_total와 df_test 데이터를 head, tail. describe, info 등을 활용하여 확인하세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_total.head()
# Out:
#          기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 256   20170101      0  31535.2200      1945.4402         566.4588
# 680   20170101      1  31188.9174      1930.4766         562.1018
# 1104  20170101      2  31240.4974      1921.1864         559.3965
# 1528  20170101      3  31442.4314      1946.4476         566.7525
# 1952  20170101      4  31922.7751      1953.7713         568.8845
#
#       남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 256          631.5581         991.9184        1297.1287        1223.1529
# 680          625.2151        1030.6281        1307.7381        1183.0956
# 1104         658.7463        1058.7082        1311.9591        1186.2600
# 1528         649.0804        1057.9119        1324.2638        1202.1250
# 1952         623.2087        1063.2557        1342.9146        1209.2680
#
#       남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_total.tail()
# Out:
#            기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 313700  20211231     19  33060.4555      1858.2611         541.0746
# 313968  20211231     20  32360.1898      2093.8808         609.6807
# 314500  20211231     21  31417.3991      1983.6728         577.5909
# 314645  20211231     22  30763.0563      2028.3314         590.5941
# 315144  20211231     23  30404.2740      1903.8825         554.3582
#
#         남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 313700         605.9080         781.6602        1342.6763        1435.1080
# 313968         612.5326         768.8351        1323.7124        1479.1382
# 314500         639.2174         779.6693        1187.6783        1375.6785
# 314645         654.0295         790.1638        1133.6311        1362.0266
# 315144         615.0753         772.8499        1136.6157        1295.0434
#
#         남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  \
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_total.describe()
# Out:
#               기준일ID         시간대구분        총생활인구수  남자0세부터9세생활인구수  \
# count  4.351200e+04  43512.000000  43512.000000   43512.000000
# mean   2.019067e+07     11.500000  37390.662860    2148.116383
# std    1.419499e+04      6.922266   4310.755449     300.500034
# min    2.017010e+07      0.000000  27011.574900    1256.222800
# 25%    2.018033e+07      5.750000  33875.737425    1949.556800
# 50%    2.019063e+07     11.500000  36894.775800    2110.842250
# 75%    2.020100e+07     17.250000  40337.888175    2319.439625
# max    2.021123e+07     23.000000  55160.667300    5732.894600
#
#        남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# count     43512.000000     43512.000000     43512.000000     43512.000000
# mean        625.472466       780.302694      1281.098112      1527.965879
# std          87.497350       133.564721       254.313828       243.519957
# min         365.777800       433.762600       638.408000       944.904700
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43512 entries, 256 to 315144
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   기준일ID            43512 non-null  int64
#  1   시간대구분            43512 non-null  int64
#  2   총생활인구수           43512 non-null  float64
#  3   남자0세부터9세생활인구수    43512 non-null  float64
#  4   남자10세부터14세생활인구수  43512 non-null  float64
#  5   남자15세부터19세생활인구수  43512 non-null  float64
#  6   남자20세부터24세생활인구수  43512 non-null  float64
#  7   남자25세부터29세생활인구수  43512 non-null  float64
#  8   남자30세부터34세생활인구수  43512 non-null  float64
#  9   남자35세부터39세생활인구수  43512 non-null  float64
#  10  남자40세부터44세생활인구수  43512 non-null  float64
#  11  남자45세부터49세생활인구수  43512 non-null  float64
#  12  남자50세부터54세생활인구수  43512 non-null  float64
#  13  남자55세부터59세생활인구수  43512 non-null  float64
#  14  남자60세부터64세생활인구수  43512 non-null  float64
#  15  남자65세부터69세생활인구수  43512 non-null  float64
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_test.head()
# Out:
#          기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 100   20220101      0  30509.7386      1884.2082         548.6298
# 431   20220101      1  30759.5067      1918.5330         558.6242
# 922   20220101      2  31048.8787      2068.1943         602.2013
# 1337  20220101      3  31076.1092      1951.7702         568.3016
# 1765  20220101      4  31714.9309      2058.5797         599.4019
#
#       남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 100          635.1617         816.1686        1140.0136        1310.3109
# 431          665.6793         822.6910        1159.5614        1293.1350
# 922          680.8294         819.7141        1164.5819        1331.9311
# 1337         690.9847         804.2219        1180.7028        1336.8848
# 1765         708.3313         847.9704        1168.0681        1355.7735
#
#       남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_test.tail()
# Out:
#            기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 303256  20220630     19  32969.6040      2108.4754         613.9301
# 303649  20220630     20  31014.6597      2017.9104         587.5599
# 304418  20220630     21  30923.2923      2083.7634         606.7347
# 304799  20220630     22  30509.5463      2186.0950         636.5307
# 305043  20220630     23  31184.8763      2179.2547         634.5390
#
#         남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 303256         565.6419         904.1955        1338.8420        1416.2874
# 303649         542.7330         826.7983        1210.9392        1313.6926
# 304418         544.7149         813.5115        1175.5524        1279.7073
# 304799         573.6676         755.8347        1156.8269        1230.5487
# 305043         580.9860         711.6332        1212.8320        1308.7377
#
#         남자35세부터39세생활인구수  ...  여자25세부터29세생활인구수  여자30세부터34세생활인구수  \
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_test.describe()
# Out:
#               기준일ID        시간대구분        총생활인구수  남자0세부터9세생활인구수  \
# count  4.344000e+03  4344.000000   4344.000000    4344.000000
# mean   2.022037e+07    11.500000  36003.921997    2325.550717
# std    1.712987e+02     6.922983   3553.140560     309.575554
# min    2.022010e+07     0.000000  28168.691000    1535.927200
# 25%    2.022022e+07     5.750000  33135.555000    2131.500900
# 50%    2.022040e+07    11.500000  35471.666550    2273.385150
# 75%    2.022052e+07    17.250000  38221.242725    2438.792775
# max    2.022063e+07    23.000000  55541.842300    3942.967200
#
#        남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# count      4344.000000      4344.000000      4344.000000      4344.000000
# mean        677.136467       649.775589       886.934272      1310.851562
# std          90.139893       110.616291       105.890912       113.693016
# min         447.219700       357.654200       589.750400       913.591700
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4344 entries, 100 to 305043
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   기준일ID            4344 non-null   int64
#  1   시간대구분            4344 non-null   int64
#  2   총생활인구수           4344 non-null   float64
#  3   남자0세부터9세생활인구수    4344 non-null   float64
#  4   남자10세부터14세생활인구수  4344 non-null   float64
#  5   남자15세부터19세생활인구수  4344 non-null   float64
#  6   남자20세부터24세생활인구수  4344 non-null   float64
#  7   남자25세부터29세생활인구수  4344 non-null   float64
#  8   남자30세부터34세생활인구수  4344 non-null   float64
#  9   남자35세부터39세생활인구수  4344 non-null   float64
#  10  남자40세부터44세생활인구수  4344 non-null   float64
#  11  남자45세부터49세생활인구수  4344 non-null   float64
#  12  남자50세부터54세생활인구수  4344 non-null   float64
#  13  남자55세부터59세생활인구수  4344 non-null   float64
#  14  남자60세부터64세생활인구수  4344 non-null   float64
#  15  남자65세부터69세생활인구수  4344 non-null   float64
# ...

# %% [markdown]
# ---

# %% [markdown]
# # 3. 데이터 분석하기
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 관측치들의 패턴 탐색
#   * 잘못된 자료들을 탐색
#   * 변수들간의 관계 파악

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %% [markdown]
# #### [실습문제5] 데이터 형태 변경하기
# * df_total, df_test의 index를 리셋 하고, ['기준일ID']에 to_datetime 함수를 사용하여 데이터 형태를 변경하세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_total.reset_index(inplace=True,drop=True)



df_test.reset_index(inplace=True, drop=True)

df_total
# Out:
#           기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0      20170101      0  31535.2200      1945.4402         566.4588
# 1      20170101      1  31188.9174      1930.4766         562.1018
# 2      20170101      2  31240.4974      1921.1864         559.3965
# 3      20170101      3  31442.4314      1946.4476         566.7525
# 4      20170101      4  31922.7751      1953.7713         568.8845
# ...         ...    ...         ...            ...              ...
# 43507  20211231     19  33060.4555      1858.2611         541.0746
# 43508  20211231     20  32360.1898      2093.8808         609.6807
# 43509  20211231     21  31417.3991      1983.6728         577.5909
# 43510  20211231     22  30763.0563      2028.3314         590.5941
# 43511  20211231     23  30404.2740      1903.8825         554.3582
#
#        남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0             631.5581         991.9184        1297.1287        1223.1529
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_total['기준일ID'] = pd.to_datetime(df_total['기준일ID'], format='%Y%m%d')
df_test['기준일ID'] = pd.to_datetime(df_test['기준일ID'], format='%Y%m%d')

# %% [markdown]
# #### [실습문제6] 데이터 분포 알아보기
# * df_total 및 df_test의 '총생활인구수' 변수를 기준으로 각종 Chart를 그려보고 인사이트를 도출해보세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

plt.figure(figsize=(20,4))
plt.plot(df_total['총생활인구수'], data = df_total)

# %%
plt.figure(figsize=(20,4))
plt.plot(df_test['총생활인구수'], data = df_total)

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

temp = df_total[-100:]
plt.figure(figsize = (20,8))
plt.plot(temp['총생활인구수'], marker ='o')

# %%
plt.hist(df_total['총생활인구수'])
# Out:
# (array([3.7900e+02, 5.7730e+03, 1.0125e+04, 1.0157e+04, 8.0970e+03,
#         4.9620e+03, 3.2100e+03, 7.3700e+02, 6.6000e+01, 6.0000e+00]),
#  array([27011.5749 , 29826.48414, 32641.39338, 35456.30262, 38271.21186,
#         41086.1211 , 43901.03034, 46715.93958, 49530.84882, 52345.75806,
#         55160.6673 ]),
#  <a list of 10 Patch objects>)

# %%
# 위 차트를 통해 알게된 사실을 정리해봅시다.
# 1. 
# 2.
# 3.

# %% [markdown]
# ## 다음 단계를 위해서 데이터를 저장하겠습니다.

# %%
# CSV로 저장
df_total.to_csv('df_total.csv', index=False)
df_test.to_csv('df_test.csv', index=False)

# %% [markdown]
# # 4. (참고) 시계열 분석 기초 (Stationary / Normality)
#
# * 아래 주어진 코드를 기반으로 해당 데이터가 정상성과 정규성을 충족 하는지 확인해봅시다

# %% [markdown]
# #### [실습문제7] 정상성 분석
# * df_total['총생활인구수'] 데이터가 정상성을 띄는지 확인해보도록 하겠습니다
#
# * 정상성을 띈다 = 시계열 데이터의 평균과 분산이 일정하다.
#     - Dickey Fuller test 를 활용합니다
#     - Stationary (p-value < 0.05)
#
# ---
#
# * 귀무가설 : H0 : 시계열 데이터에 unit root를 포함한다 : nonstatinary / 정상 시계열이 아니다.
# * 대립가설 : H1 : 시계열 데이터에 unit root를 포함하지 않는다 : 정상 시계열이다.
# ---

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
from statsmodels.tsa.stattools import adfuller

def adf_test(y):
    dftest = adfuller(y, autolag='AIC')
    # autolag 'AIC' : 검정 AR 모형의 차수를 자동으로 결정
    dfoutput = pd.Series(dftest[0:4], index=['test statistic', 'p-value', '# of lags', '# of observations'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value ({})'.format(key)] = value
    print(dfoutput)

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

adf_test(df_total['총생활인구수'])
# Out:
# test statistic         -8.946524e+00
# p-value                 8.957713e-15
# # of lags               5.500000e+01
# # of observations       4.345600e+04
# Critical Value (1%)    -3.430500e+00
# Critical Value (5%)    -2.861607e+00
# Critical Value (10%)   -2.566805e+00
# dtype: float64

# %%
# test statistic 검정 통계량 - 회귀 분석의 결과로 나타나는 계수
# p-value : p-value 추정치
# # of lags : 사용된 시차의 수(used lags)
# # of observations : 분석에 사용된 자료의 수

# critical values : 1%, 5%, 10%수준에 해당되는 검정 통계량의 값

# %% [markdown]
# #### [실습문제8] 정규성 분석
# * df_total['총생활인구수'] 데이터가 정규성을 띄는지 확인해보도록 하겠습니다
#
# * 정규성을 띈다 = 데이터의 분포가 정규분포를 이룬다.
#     * Shapiro test 를 활용합니다
#     * Normality (p-value > 0.05)
#
# ---
# * 귀무가설 : H0 : 시계열 데이터가 정규성을 충족한다.
# * 대립가설 : H1 : 시계열 데이터가 정규성을 충족하지 않는다.
# ---

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
from scipy import stats
from scipy.stats import shapiro

# %%
shapiro_test = stats.shapiro(df_total['총생활인구수'])
shapiro_test
# Out:
# ShapiroResult(statistic=0.9755643606185913, pvalue=0.0)

# %%
# shapiro wilk test의 특징 : 데이터 수가 5000을 초과 하는 경우, 
#                      정규성 검정에 대한 p-value를 담보하지 못한다.(통계적 유의성이 떨어진다.)

# shapiro wilk 정규성 검정에서는 p-value 가 유의수준 0.05보다 클 경우 정규분포를 따른다고 판단 할 수 있음. 
# 시계열 데이터가 정규성을 충족하지 않습니다.

# %%
from scipy.stats import anderson
anderson(df_total['총생활인구수'])
# Out:
# AndersonResult(statistic=295.90222305037605, critical_values=array([0.576, 0.656, 0.787, 0.918, 1.092]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %%
# statistic : 검정 통계값 (295.90)
# critical_values    : 임계값 - (0.576, 0.656, 0.787, 0.918, 1.092)
# significance_level : 알파값 - (0.15,  0.1.   0.05,  0.025, 0.01)

# anderson- darling test 는 검정 통계값과 임계값을 비교해서 확인 할 수 있다.
# -> 알파값 0.01에 대해서 임계값이 1.092 이고, 검정통계값이 295이므로, 이는 검정 통계값보다 임계값이 작으므로 결과는 유의수준(알파값)에서 유의하다
# -> 쉽게 말해서 임계값과 검정 통계값을 비교하여 검정 통계값보다 더 작으면 정규분포를 따르지 않는다.
